# %%
include("../../src/GaPSE.jl");

# %%
using DelimitedFiles, Plots, Dierckx, SpecialFunctions, Printf, LaTeXStrings

# %%
FILE_F_MAP = "../../test/datatest/F_REFERENCE.txt"
FILE_PS = "../../test/datatest/file_pk.txt"
FILE_BACKGROUND = "../../test/datatest/WideA_ZA_background.dat"

z_min = 0.05
z_max = 0.20
θ_max = π / 2.0
params = GaPSE.CosmoParams(z_min, z_max, θ_max;
  k_min = 1e-8, k_max = 10.0,
  Ω_b = 0.0489, Ω_cdm = 0.251020, h_0 = 0.70,
    N = 1024, fit_min = 0.05, fit_max= 0.5, con=true)

cosmo = GaPSE.Cosmology(params, FILE_BACKGROUND, FILE_PS, FILE_F_MAP; expand=false)

GaPSE.parameters_used(stdout, cosmo)
# Out:
# I take the input power spectrum as it is,without expanding.
# # The following parameters were used for this computation:
# # CLASS Power Spectrum input file : "../../test/datatest/file_pk.txt"
# # F window function input file : "../../test/datatest/F_REFERENCE.txt"
# # CLASS Background input file: "../../test/datatest/WideA_ZA_background.dat"
# # 	 z_min = 0.05 	 z_max = 0.2
# # 	 k_min = 1.0e-8 	 k_max = 10.0
# # 	 h_0 = 0.7 	 Ω_b = 0.0489 	 Ω_cdm = 0.25102 	 Ω_M0 = 0.29992
# # 	 comoving s_min = 148.19200014818588 Mpc/h_0
# # 	 comoving s_max = 571.7022420258767 Mpc/h_0
# # 	 comoving s_eff = 435.3747095691862 Mpc/h_0
# # 	 comoving z_eff = 0.15045636096027523
# # 	 Volume of the survey V_survey = 3.845366167993746e8
# # 	 σ_0 = 15.593462966741178
# # 	 σ_1 = 15.074895881392285
# # 	 σ_2 = 100.85852368830221
# # 	 σ_3 = 3735.1227501923527
# #

# %%
GaPSE.print_map_ξ_multipole(cosmo, "xi_lensingintegratedgp_L0.txt","lensing_integratedgp"; use_windows = false, 
    N_χs = 50, N_μs = 30)
# Out:
# Input point out of range
#
# Stacktrace:
#   [1] error(s::String)
#     @ Base ./error.jl:33
#   [2] _evaluate(t::Vector{Float64}, c::Vector{Float64}, k::Int64, x::Float64, bc::Int64)
#     @ Dierckx ~/.julia/packages/Dierckx/xFcLv/src/Dierckx.jl:286
#   [3] evaluate
#     @ ~/.julia/packages/Dierckx/xFcLv/src/Dierckx.jl:296 [inlined]
#   [4] Spline1D
#     @ ~/.julia/packages/Dierckx/xFcLv/src/Dierckx.jl:1040 [inlined]
#   [5] integrand_ξ_lensingintegratedgp(IP1::Main.GaPSE.Point, IP2::Main.GaPSE.Point, P1::Main.GaPSE.Point, P2::Main.GaPSE.Point, y::Float64, cosmo::Main.GaPSE.Cosmology; Δχ_min::Float64)
#     @ Main.GaPSE ~/AAA_TESI_MAGISTRALE/GaPSE/src/CrossCorrelations/LensingIntegratedGP.jl:117
#   [6] #186
#     @ ./none:0 [inlined]
#   [7] iterate
#     @ ./generator.jl:47 [inlined]
#   [8] collect(itr::Base.Generator{Base.Iterators.ProductIterator{Tuple{Vector{Main.GaPSE.Point}, Vector{Main.GaPSE.Point}}}, Main.GaPSE.var"#186#189"{Float64, Float64, Main.GaPSE.Point, Main.GaPSE.Point, Float64, Main.GaPSE.Cosmology}})
#     @ Base ./array.jl:724
#   [9] ξ_lensingintegratedgp(P1::Main.GaPSE.Point, P2::Main.GaPSE.Point, y::Float64, cosmo::Main.GaPSE.Cosmology; en::Float64, N_χs::Int64, Δχ_min::Float64)
#     @ Main.GaPSE ~/AAA_TESI_MAGISTRALE/GaPSE/src/CrossCorrelations/LensingIntegratedGP.jl:238
#  [10] #ξ_lensingintegratedgp#190
#     @ ~/AAA_TESI_MAGISTRALE/GaPSE/src/CrossCorrelations/LensingIntegratedGP.jl:251 [inlined]
#  [11] int_on_mu_lensingintegratedgp(s1::Float64, s::Float64, μ::Float64, cosmo::Main.GaPSE.Cosmology; L::Int64, en::Float64, use_windows::Bool, Δχ_min::Float64, N_χs::Int64)
#     @ Main.GaPSE ~/AAA_TESI_MAGISTRALE/GaPSE/src/CrossCorrelations/LensingIntegratedGP.jl:341
#  [12] orig_f
#     @ ~/AAA_TESI_MAGISTRALE/GaPSE/src/XiMultipoles.jl:29 [inlined]
#  [13] _broadcast_getindex_evalf
#     @ ./broadcast.jl:670 [inlined]
#  [14] _broadcast_getindex
#     @ ./broadcast.jl:643 [inlined]
#  [15] getindex
#     @ ./broadcast.jl:597 [inlined]
#  [16] macro expansion
#     @ ./broadcast.jl:961 [inlined]
#  [17] macro expansion
#     @ ./simdloop.jl:77 [inlined]
#  [18] copyto!
#     @ ./broadcast.jl:960 [inlined]
#  [19] copyto!
#     @ ./broadcast.jl:913 [inlined]
#  [20] copy
#     @ ./broadcast.jl:885 [inlined]
#  [21] materialize
#     @ ./broadcast.jl:860 [inlined]
#  [22] integral_on_mu(s1::Float64, s::Float64, integrand::typeof(Main.GaPSE.int_on_mu_lensingintegratedgp), cosmo::Main.GaPSE.Cosmology; enhancer::Float64, N_μs::Int64, μ_atol::Float64, μ_rtol::Float64, kwargs::Base.Pairs{Symbol, Integer, Tuple{Symbol, Symbol, Symbol}, NamedTuple{(:L, :use_windows, :N_χs), Tuple{Int64, Bool, Int64}}})
#     @ Main.GaPSE ~/AAA_TESI_MAGISTRALE/GaPSE/src/XiMultipoles.jl:38
#  [23] integral_on_mu(s1::Float64, s::Float64, effect::String, cosmo::Main.GaPSE.Cosmology; kwargs::Base.Pairs{Symbol, Integer, NTuple{4, Symbol}, NamedTuple{(:L, :use_windows, :N_χs, :N_μs), Tuple{Int64, Bool, Int64, Int64}}})
#     @ Main.GaPSE ~/AAA_TESI_MAGISTRALE/GaPSE/src/XiMultipoles.jl:54
#  [24] #222
#     @ ./none:0 [inlined]
#  [25] iterate
#     @ ./generator.jl:47 [inlined]
#  [26] collect(itr::Base.Generator{ProgressMeter.ProgressWrapper{Vector{Float64}}, Main.GaPSE.var"#222#223"{Base.Pairs{Symbol, Integer, NTuple{4, Symbol}, NamedTuple{(:L, :use_windows, :N_χs, :N_μs), Tuple{Int64, Bool, Int64, Int64}}}, Main.GaPSE.Cosmology, String, Float64}})
#     @ Base ./array.jl:724
#  [27] macro expansion
#     @ ~/.julia/packages/ProgressMeter/Vf8un/src/ProgressMeter.jl:947 [inlined]
#  [28] map_integral_on_mu(cosmo::Main.GaPSE.Cosmology, effect::String, v_ss::Nothing; s_1::Float64, pr::Bool, kwargs::Base.Pairs{Symbol, Integer, NTuple{4, Symbol}, NamedTuple{(:L, :use_windows, :N_χs, :N_μs), Tuple{Int64, Bool, Int64, Int64}}})
#     @ Main.GaPSE ~/AAA_TESI_MAGISTRALE/GaPSE/src/XiMultipoles.jl:165
#  [29] #map_ξ_multipole#224
#     @ ~/AAA_TESI_MAGISTRALE/GaPSE/src/XiMultipoles.jl:181 [inlined]
#  [30] print_map_ξ_multipole(cosmo::Main.GaPSE.Cosmology, out::String, effect::String, v_ss::Nothing; s_1::Nothing, kwargs::Base.Pairs{Symbol, Integer, Tuple{Symbol, Symbol, Symbol}, NamedTuple{(:use_windows, :N_χs, :N_μs), Tuple{Bool, Int64, Int64}}})
#     @ Main.GaPSE ~/AAA_TESI_MAGISTRALE/GaPSE/src/XiMultipoles.jl:236
#  [31] top-level scope
#     @ In[4]:1
#  [32] eval
#     @ ./boot.jl:373 [inlined]
#  [33] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1196

# %%
my_table = readdlm("xi_lensingintegratedgp_L0.txt", comments=true);
my_ss = convert(Vector{Float64}, my_table[:,1]);
my_lensingintegratedgps = convert(Vector{Float64}, my_table[:,2]);
mattia_table = readdlm("/Users/matteofoglieni/Dropbox/GR_effects/Mattia_Output/Monopoles_without_window/xi_lensing_integrated_L0.txt")
mattia_ss = convert(Vector{Float64}, mattia_table[2:end, 1]);
mattia_lensingintegratedgps = convert(Vector{Float64}, mattia_table[2:end, 2]);
#casto_table = readdlm("tab_kappa_terms.dat")
#casto_ss = convert(Vector{Float64}, casto_table[3:end, 1]);
#casto_lensings = convert(Vector{Float64}, casto_table[3:end, 2]);

# %%
my_xs = my_ss
my_ys = my_lensingintegratedgps
xs = mattia_ss
ys = mattia_lensingintegratedgps
spline = Spline1D(xs, ys)
K_VLINE = 150

p1 = plot([my_xs, xs], [my_ys,  ys], #xaxis=:log, #yaxis=:log, 
    lc=[:red :blue], label=["My Lensingintegratedgp" "Mattia Lensingintegratedgp"], 
    ls=[:dash :solid], legend=:bottomleft)
vline!(p1,[K_VLINE], lc=:black, ls=:dash)


p2 = plot(my_xs, spline.(my_xs) .- my_ys, 
    xaxis=:log,label="Difference", lc=:green, legend=:bottomright)
vline!(p2,[K_VLINE], lc=:black, ls=:dash)

p3 = plot(my_xs, spline.(my_xs) ./ my_ys, label="Ratio", lc=:green, xaxis=:log,
    #ylim=(0.99,1.05)
)
vline!(p3,[K_VLINE], lc=:black, ls=:dash)

plot(p1, p2, p3, size=(650, 600), layout= @layout [ x ; y z ] )

# %%
my_xs = my_ss
my_ys = my_lensingintegratedgps
xs = mattia_ss
ys = mattia_lensingintegratedgps
spline = Spline1D(xs, ys)

S_VLIM = cosmo.s_eff
S_VLIM_F = @sprintf("%.2f", S_VLIM)

p1 = plot([my_xs, xs], [my_ys,  ys], xaxis=:log, #yaxis=:log, 
    lc=[:red :blue], 
    label=["My LensingIntegratedGP" "Mattia LensingIntegratedGP"], ls=[:dash :solid], 
    legend=:topleft)
vline!(p1, [S_VLIM], label="$S_VLIM_F Mpc/h_0", lc=:black, lw=0.5, ls=:dash)

p2 = plot(my_xs, spline.(my_xs) ./ my_ys, label="Ratio", lc=:green, xaxis=:log,
    ylim=(0.99,1.01), legend=:topleft,
    xlabel=L"$s \quad [h_0^{-1}\,\mathrm{Mpc}]$")
vline!(p2, [S_VLIM], label="$S_VLIM_F Mpc/h_0", lc=:black, lw=0.5, ls=:dash)

P = plot(p1, p2, size=(550, 500), layout= @layout [ x ; z ] )
savefig(P, "xi_AutoIntegratedGP_L0.pdf")
display(P)
