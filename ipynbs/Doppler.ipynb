# %%
include("../src/GaPSE.jl");

# %%
using DelimitedFiles, Plots, Dierckx, SpecialFunctions

# %%
FILE_F_MAP = "../data/F_REFERENCE.txt"
#FILE_PS = "../data/WideA_ZA_pk.dat"
FILE_PS = "file_pk.txt"
FILE_BACKGROUND = "../data/WideA_ZA_background.dat"
#FILE_IS = "tab_xi.txt"

z_min = 0.05
z_max = 0.20
θ_max = π / 2.0
params = GaPSE.CosmoParams(z_min, z_max, θ_max;
  k_min = 1e-8, k_max = 10.0,
  Ω_b = 0.0489, Ω_cdm = 0.251020, h_0 = 0.70,
    N = 1024, fit_min = 0.05, fit_max= 0.5, con=true)

cosmo = GaPSE.Cosmology(params, FILE_BACKGROUND, FILE_PS, FILE_F_MAP; expand=false)

GaPSE.parameters_used(stdout, cosmo)
# Out:
# 4593
# 847.0324976648
# 4567
# I take the input power spectrum as it is,without expanding.
# l_si, l_b, l_a = -2.000245517236617 , -16.80633322303903 , 0.10603211333142491
# r_si, r_b, r_a = -3.5566741647984137 , -18561.189022728868 , 2.343399564267213e-10
# # The following parameters were used for this computation:
# # CLASS Power Spectrum input file : "file_pk.txt"
# # F window function input file : "../data/F_REFERENCE.txt"
# # CLASS Background input file: "../data/WideA_ZA_background.dat"
# # 	 z_min = 0.05 	 z_max = 0.2
# # 	 k_min = 1.0e-8 	 k_max = 10.0
# # 	 h_0 = 0.7 	 Ω_b = 0.0489 	 Ω_cdm = 0.25102 	 Ω_M0 = 0.29992
# # 	 comoving s_min = 148.1920001343431 Mpc/h_0
# # 	 comoving s_max = 571.7022420258767 Mpc/h_0
# # 	 comoving s_eff = 435.3747095674343 Mpc/h_0
# # 	 comoving z_eff = 0.1504563609596467
# # 	 Volume of the survey V_survey = 3.845366168012846e8
# # 	 σ_0 = 15.593462966741178
# # 	 σ_1 = 15.074895881392285
# # 	 σ_2 = 100.85852368830221
# # 	 σ_3 = 3735.1227501923527
# #

# %%
GaPSE.print_map_ξ_multipole(cosmo,
    "AutoCorrelationTests/xi_doppler_L0.txt",
    "auto_doppler"; use_windows = false,
    enhancer = 1e6, use_my = false, μ_rtol=1e-3, μ_atol=1e-8)
# Out:
# Progress:   2%|▉                                        |  ETA: 0:00:45
# I will use quadgk.
# Input point out of range
#
# Stacktrace:
#   [1] error(s::String)
#     @ Base ./error.jl:33
#   [2] _evaluate(t::Vector{Float64}, c::Vector{Float64}, k::Int64, x::Float64, bc::Int64)
#     @ Dierckx ~/.julia/packages/Dierckx/xFcLv/src/Dierckx.jl:286
#   [3] evaluate
#     @ ~/.julia/packages/Dierckx/xFcLv/src/Dierckx.jl:296 [inlined]
#   [4] Spline1D
#     @ ~/.julia/packages/Dierckx/xFcLv/src/Dierckx.jl:1040 [inlined]
#   [5] Main.GaPSE.Point(s::Float64, cosmo::Main.GaPSE.Cosmology)
#     @ Main.GaPSE ~/AAA_TESI_MAGISTRALE/GaPSE/src/Cosmology.jl:113
#   [6] integrand_on_mu_doppler(s1::Float64, s::Float64, μ::Float64, cosmo::Main.GaPSE.Cosmology; L::Int64, enhancer::Float64, use_windows::Bool)
#     @ Main.GaPSE ~/AAA_TESI_MAGISTRALE/GaPSE/src/AutoCorrelations/AutoDoppler.jl:157
#   [7] f
#     @ ~/AAA_TESI_MAGISTRALE/GaPSE/src/XiMultipoles.jl:28 [inlined]
#   [8] #173
#     @ ~/AAA_TESI_MAGISTRALE/GaPSE/src/XiMultipoles.jl:31 [inlined]
#   [9] evalrule(f::Main.GaPSE.var"#173#175"{Main.GaPSE.var"#f#174"{Float64, Base.Pairs{Symbol, Integer, Tuple{Symbol, Symbol}, NamedTuple{(:L, :use_windows), Tuple{Int64, Bool}}}, Float64, Float64, typeof(Main.GaPSE.integrand_on_mu_doppler), Main.GaPSE.Cosmology}}, a::Float64, b::Float64, x::Vector{Float64}, w::Vector{Float64}, gw::Vector{Float64}, nrm::typeof(LinearAlgebra.norm))
#     @ QuadGK ~/.julia/packages/QuadGK/ENhXl/src/evalrule.jl:21
#  [10] #2
#     @ ~/.julia/packages/QuadGK/ENhXl/src/adapt.jl:10 [inlined]
#  [11] ntuple
#     @ ./ntuple.jl:48 [inlined]
#  [12] do_quadgk(f::Main.GaPSE.var"#173#175"{Main.GaPSE.var"#f#174"{Float64, Base.Pairs{Symbol, Integer, Tuple{Symbol, Symbol}, NamedTuple{(:L, :use_windows), Tuple{Int64, Bool}}}, Float64, Float64, typeof(Main.GaPSE.integrand_on_mu_doppler), Main.GaPSE.Cosmology}}, s::Tuple{Float64, Float64}, n::Int64, atol::Float64, rtol::Float64, maxevals::Int64, nrm::typeof(LinearAlgebra.norm))
#     @ QuadGK ~/.julia/packages/QuadGK/ENhXl/src/adapt.jl:10
#  [13] #28
#     @ ~/.julia/packages/QuadGK/ENhXl/src/adapt.jl:179 [inlined]
#  [14] handle_infinities(workfunc::QuadGK.var"#28#29"{Float64, Float64, Int64, Int64, typeof(LinearAlgebra.norm)}, f::Main.GaPSE.var"#173#175"{Main.GaPSE.var"#f#174"{Float64, Base.Pairs{Symbol, Integer, Tuple{Symbol, Symbol}, NamedTuple{(:L, :use_windows), Tuple{Int64, Bool}}}, Float64, Float64, typeof(Main.GaPSE.integrand_on_mu_doppler), Main.GaPSE.Cosmology}}, s::Tuple{Float64, Float64})
#     @ QuadGK ~/.julia/packages/QuadGK/ENhXl/src/adapt.jl:113
#  [15] quadgk(::Function, ::Float64, ::Float64; atol::Float64, rtol::Float64, maxevals::Int64, order::Int64, norm::Function)
#     @ QuadGK ~/.julia/packages/QuadGK/ENhXl/src/adapt.jl:177
#  [16] integral_on_mu(s1::Float64, s::Float64, integrand::Function, cosmo::Main.GaPSE.Cosmology; enhancer::Float64, μ_atol::Float64, μ_rtol::Float64, kwargs::Base.Pairs{Symbol, Integer, Tuple{Symbol, Symbol}, NamedTuple{(:L, :use_windows), Tuple{Int64, Bool}}})
#     @ Main.GaPSE ~/AAA_TESI_MAGISTRALE/GaPSE/src/XiMultipoles.jl:31
#  [17] integral_on_mu(s1::Float64, s::Float64, effect::String, cosmo::Main.GaPSE.Cosmology; kwargs::Base.Pairs{Symbol, Real, NTuple{5, Symbol}, NamedTuple{(:L, :use_windows, :enhancer, :μ_rtol, :μ_atol), Tuple{Int64, Bool, Float64, Float64, Float64}}})
#     @ Main.GaPSE ~/AAA_TESI_MAGISTRALE/GaPSE/src/XiMultipoles.jl:44
#  [18] f
#     @ ~/AAA_TESI_MAGISTRALE/GaPSE/src/XiMultipoles.jl:200 [inlined]
#  [19] #185
#     @ ./none:0 [inlined]
#  [20] iterate
#     @ ./generator.jl:47 [inlined]
#  [21] collect_to!(dest::Vector{Tuple{Float64, Float64}}, itr::Base.Generator{ProgressMeter.ProgressWrapper{Vector{Float64}}, Main.GaPSE.var"#185#191"{Main.GaPSE.var"#f#190"{Base.Pairs{Symbol, Real, NTuple{5, Symbol}, NamedTuple{(:L, :use_windows, :enhancer, :μ_rtol, :μ_atol), Tuple{Int64, Bool, Float64, Float64, Float64}}}, Main.GaPSE.Cosmology, String, Float64}}}, offs::Int64, st::Int64)
#     @ Base ./array.jl:782
#  [22] collect_to_with_first!(dest::Vector{Tuple{Float64, Float64}}, v1::Tuple{Float64, Float64}, itr::Base.Generator{ProgressMeter.ProgressWrapper{Vector{Float64}}, Main.GaPSE.var"#185#191"{Main.GaPSE.var"#f#190"{Base.Pairs{Symbol, Real, NTuple{5, Symbol}, NamedTuple{(:L, :use_windows, :enhancer, :μ_rtol, :μ_atol), Tuple{Int64, Bool, Float64, Float64, Float64}}}, Main.GaPSE.Cosmology, String, Float64}}}, st::Int64)
#     @ Base ./array.jl:760
#  [23] collect(itr::Base.Generator{ProgressMeter.ProgressWrapper{Vector{Float64}}, Main.GaPSE.var"#185#191"{Main.GaPSE.var"#f#190"{Base.Pairs{Symbol, Real, NTuple{5, Symbol}, NamedTuple{(:L, :use_windows, :enhancer, :μ_rtol, :μ_atol), Tuple{Int64, Bool, Float64, Float64, Float64}}}, Main.GaPSE.Cosmology, String, Float64}}})
#     @ Base ./array.jl:734
#  [24] macro expansion
#     @ ~/.julia/packages/ProgressMeter/Vf8un/src/ProgressMeter.jl:947 [inlined]
#  [25] map_integral_on_mu(cosmo::Main.GaPSE.Cosmology, effect::String, v_ss::Nothing; s_1::Float64, use_my::Bool, pr::Bool, kwargs::Base.Pairs{Symbol, Real, NTuple{5, Symbol}, NamedTuple{(:L, :use_windows, :enhancer, :μ_rtol, :μ_atol), Tuple{Int64, Bool, Float64, Float64, Float64}}})
#     @ Main.GaPSE ~/AAA_TESI_MAGISTRALE/GaPSE/src/XiMultipoles.jl:201
#  [26] map_ξ_multipole(cosmo::Main.GaPSE.Cosmology, effect::String, v_ss::Nothing; L::Int64, kwargs::Base.Pairs{Symbol, Real, NTuple{6, Symbol}, NamedTuple{(:s_1, :use_windows, :enhancer, :use_my, :μ_rtol, :μ_atol), Tuple{Float64, Bool, Float64, Bool, Float64, Float64}}})
#     @ Main.GaPSE ~/AAA_TESI_MAGISTRALE/GaPSE/src/XiMultipoles.jl:219
#  [27] print_map_ξ_multipole(cosmo::Main.GaPSE.Cosmology, out::String, effect::String, v_ss::Nothing; s_1::Nothing, kwargs::Base.Pairs{Symbol, Real, NTuple{5, Symbol}, NamedTuple{(:use_windows, :enhancer, :use_my, :μ_rtol, :μ_atol), Tuple{Bool, Float64, Bool, Float64, Float64}}})
#     @ Main.GaPSE ~/AAA_TESI_MAGISTRALE/GaPSE/src/XiMultipoles.jl:274
#  [28] top-level scope
#     @ In[4]:1
#  [29] eval
#     @ ./boot.jl:373 [inlined]
#  [30] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1196

# %%
tab_pk = readdlm("file_pk.txt", comments=true);
ks = convert(Vector{Float64}, tab_pk[:,1]);
k_min, k_max = ks[begin], ks[end]
pks = convert(Vector{Float64}, tab_pk[:,2]);
PK = Spline1D(ks, pks);

# %%
my_table = readdlm("AutoCorrelationTests/xi_doppler_L0.txt", comments=true)
my_ss = convert(Vector{Float64}, my_table[:, 1]);
my_dopplers = convert(Vector{Float64}, my_table[:, 2]);
mattia_table = readdlm("/Users/matteofoglieni/Dropbox/GR_effects/Mattia_Output/Monopoles_without_window/xi_doppler_L0.txt")
mattia_ss = convert(Vector{Float64}, mattia_table[2:end, 1]);
mattia_dopplers = convert(Vector{Float64}, mattia_table[2:end, 2]);

# %%
my_xs = my_ss
my_ys = my_dopplers
xs = mattia_ss
ys = mattia_dopplers
spline = Spline1D(xs, ys)

S_VLIM=150

p1 = plot([my_xs, xs], [my_ys,  ys], xaxis=:log, yaxis=:log, lc=[:red :blue], 
    label=["My Doppler" "Mattia Doppler"], ls=[:dash :solid], legend=:topleft)
vline!(p1, [S_VLIM])

p2 = plot(my_xs, spline.(my_xs) .- my_ys, 
    xaxis=:log,label="Difference", lc=:green, legend=:bottomright)
vline!(p2, [S_VLIM])

p3 = plot(my_xs, spline.(my_xs) ./ my_ys, label="Ratio", lc=:green, xaxis=:log,
    ylim=(0.99,1.01))
vline!(p3, [S_VLIM])

plot(p1, p2, p3, size=(650, 600), layout= @layout [ x ; y z ] )

# %%
plot([my_xs, xs], [my_ys, ys], xaxis=:log, yaxis=:log, lc=[:red :blue], 
    label=["My Doppler" "Mattia Doppler"], ls=[:dash :solid], legend=:topleft, xlim=(300, 1e3))
